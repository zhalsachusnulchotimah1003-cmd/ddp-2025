# %% [markdown]
# <a href="https://colab.research.google.com/github/zhalsachusnulchotimah1003-cmd/ddp-2025/blob/main/praktikum_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namaKendaraan = "vario jamets"
jenisKendaraan = "motor"
ccKendaraan = 200
warnaKendaraan = "putih biru"
rodaKendaraan = 2

data_kendaraan= [namaKendaraan, jenisKendaraan, ccKendaraan, warnaKendaraan, rodaKendaraan]

print(data_kendaraan)

hargaKendaraan = 12000
tipeKendaraan = "metic"

data_kendaraan.append(hargaKendaraan)
data_kendaraan.append(tipeKendaraan)
print (data_kendaraan)

merkKendaraan = "honda"
data_kendaraan.insert(2, merkKendaraan)
print(data_kendaraan)
# Out:
# ['vario jamets', 'motor', 200, 'putih biru', 2]
# ['vario jamets', 'motor', 200, 'putih biru', 2, 12000, 'metic']
# ['vario jamets', 'motor', 'honda', 200, 'putih biru', 2, 12000, 'metic']

# %%
pilihan = input("""
Silahkan pilih menu yang diinginkan
===================================
1. Luas Persegi
2. Luas Lingkaran
3. Luas Segitiga
===================================
Kirimkan hanya angka saja,
jawaban = """)

match pilihan:
   case "1" :
    print("anda memilih luas persegi silahkan isi data dibawah")
    sisi = int(input("sisi"))
    luas = sisi * sisi
    print(f"Luas persegi dengan sisi {sisi} adalah {luas}")
    # Luas persegi
   case "2":
    # Luas Lingkaran
    # phi * jarijari**2
    print("anda memilih Luas segitiga silahkan isi data dibawah")
    jarijari = int(input("jarijari = "))
    luas = 3.14 * jarijari**2



    print(f"luas lingkaran dengan jarijari {jarijari} adalah {sisi}")
   case "3":
    # Luas segitiga
    # (alas * tinggi)/2
    print("anda memilih luas segitiga")
    alas = int(input("alas = "))
    tinggi = 13 * alas

    print(f"luas segitiga dengan alas {alas} adalah {tinggi}")
   case _:
    print("apa ya saya juga gapaham")
# Out:
# Silahkan pilih menu yang diinginkan
# ...
# 1. Luas Persegi
# 2. Luas Lingkaran
# 3. Luas Segitiga
# ...
# Kirimkan hanya angka saja,
# jawaban = 25
# apa ya saya juga gapaham
